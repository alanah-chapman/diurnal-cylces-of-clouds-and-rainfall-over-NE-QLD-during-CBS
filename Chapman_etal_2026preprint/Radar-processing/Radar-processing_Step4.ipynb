# %% [markdown]
# # Step 4: Figure 6 - Rain rate intensity and frequency computations

# %% [markdown]
# These computations are done for each site.
#
# Step 3 needs to be done before Townsville and Cairns processing; but for Willis Island no mask is needed for this figure.
# * Update `fig6_mean_rr.sh` and `fig6_rr_freq.sh` for the site to run computation for
# * Run both scripts

# %% [markdown]
# # Step 5: Figure 7 - Rain rate intensity computation for a latitudinal band

# %% [markdown]
# These computations are done only for Cairns and Willis Island.
#
# * Update `fig7_mean_rr.sh` for the site to run computation for
# * Run script
