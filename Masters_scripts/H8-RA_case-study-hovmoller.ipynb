# %% [markdown]
# # This notebook contains:
# * Code to regrid himawari-8 brightness temperature
# * Code to make hovmöller plots for Townsville for radar reflectivity and himawari-8 channel 13 brightness temperature

# %%
# import libraries
import numpy as np
import os
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import warnings
import sys
import metpy
import matplotlib
import matplotlib.gridspec as gridspec
import matplotlib.colors as mcolors
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import metpy.calc as mpcalc
import pandas as pd
from netCDF4 import Dataset
import os
import xesmf as xe
import glob
from datetime import datetime
import seaborn as sns
import netCDF4
from netCDF4 import Dataset
from metpy.units import units
import dask
import xarray as xr
from shapely import Polygon
import regionmask
import geopandas as gpd
import dask
from scipy.stats import circmean

# %%
# plot gbr locations
GBR_loc_fp = '/home/563/ac9768/Aus_Bathymetry/GBR_reef_locations.txt'# Lists to store latitude and longitude pairs
latitudes = []
longitudes = []

# Open the file and read line by line
with open(GBR_loc_fp, 'r') as file:
    for line in file:
        # Split each line into latitude and longitude
        values = line.split()
        if len(values) == 2:  # Ensure there are exactly two values on each line
            latitude, longitude = map(float, values)
            latitudes.append(latitude)
            longitudes.append(longitude)

# make an array which lists (lon,lat) reef coordinates
latitudes_array = np.array(latitudes)
longitudes_array = np.array(longitudes)
gbr_coordinates = np.column_stack((longitudes,latitudes))

# %% [markdown]
# ### Regridding himawari-8 channel 13 brightness temperature: for select cases

# %%
# define a function which stores all Himawari-8 L1 file paths from a given directory in a list
def list_files_in_directory(directory):
    """
    Parameters:
    - directory (str): Path to the parent directory of the netCDF file(s).
    
    Returns:
    - list: file paths 
    """
    file_paths = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".nc"):  # Check for the ".nc" file extension
                file_paths.append(os.path.join(root, file))
    return file_paths

directory = "/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/"
file_paths = list_files_in_directory(directory)
file_paths.sort()

# get filepaths for both case studies, date for filenames are written in format described: https://dx.doi.org/10.25914/60096221a8f7a
# case study 1: 00UTC 22-01-2022 to 00UTC 24-01-2022
case_1 = file_paths[1926:1972]
# case study 2: 12UTC 25-12-2021 to 12UTC 27-12-2021
case_2 = file_paths[1306:1355]
case_study = file_paths[2329:2497]
case_study_2021 = file_paths[:]
year_filenames = {}  
for file in file_paths:
    fn = os.path.basename(file)
    ND_day_str = fn[24:27]        # day of year in filepath string
    ND_days = int(ND_day_str)     # convert day string to integer
    if ND_days <= 100:            # removing nov-dec files
        pass
    else:
        year = fn[20:24]          # Extract the year information from the file name
        # Check if the year is already in the dictionary, if not, create a new list
        if year not in year_filenames:
            year_filenames[year] = []
        # Append the file name to the list associated with that hour
        year_filenames[year].append(file)

# Convert the dictionary values (lists of file names) to lists
yearly_file_lists = list(year_filenames.values())
case_study_2021 = yearly_file_lists
case_study_2021[0]
# Out:
# ['/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021305.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021306.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021307.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021308.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021309.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021310.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021311.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021312.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021313.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021314.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021315.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021316.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021317.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021318.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021319.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021320.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021321.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021322.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021323.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021324.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021324.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021324.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021324.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021324.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021324.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021324.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021324.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021324.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021324.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021324.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021324.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021324.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021324.130000.FLDK.R20.nc',
# ...
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021340.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021340.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021340.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021340.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021340.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021340.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021340.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021340.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021340.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021340.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021340.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021340.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021340.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021340.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021340.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021340.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021340.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021340.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021340.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021340.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021341.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021342.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021343.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021344.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.150000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.160000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.170000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.180000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.190000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.200000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.210000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.220000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021345.230000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021346.000000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021346.010000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021346.020000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021346.030000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021346.040000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021346.050000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021346.060000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021346.070000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021346.080000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021346.090000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021346.100000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021346.110000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021346.120000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021346.130000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021346.140000.FLDK.R20.nc',
#  '/g/data/v46/lb5963/HIMAWARI/08_V46_SUMM_2021-22/L1/geocatL1.HIMAWARI-8.2021346.150000.FLDK.R20.nc',
#  ...]

# %%
# define function to regrid himawari L1 files to natural resolution: creates xarray files of output grid, with time as a dimension
def diurnal_regrid_av_ch13(files):
    """
    For each file in the "files" list parameter, the file is opened, pixel_latitude and pixel_longitude variables are renamed (for regridding using xesmf) and chunked. A grid to regrid the original data to is
    created using the xesmf library for the study domain. A new dataset is created from the regridded data with longitude, latitude and time dimensions for the channel 13 brightness temperature variable.

    Parameters:
    - files (list): List of file paths to the netCDF file(s).
    
    Returns:
    - output (xarray DataSet): an xarray DataSet with longitude-latitude-time dimensions for channel 13 brightness temperature
    """
    output = []
    for file in files:
        # select elements and lines (x,y) of smaller domain size of interest (otherwise computational time will dramatically increase)
        with xr.open_dataset(file, engine="h5netcdf").sel(elements=slice(2500,3500),lines=slice(1800,2320)) as ds:
            # xesmf can only recognise 'lat' and 'lon', so rename pixel_latitude and pixel_longitude variables
            ds = ds.rename({
            "pixel_latitude": "lat",
            "pixel_longitude": "lon"
            })
            # chunk native coordinates of dataset to decreases computational time for regridding
            ds_chunked = ds.chunk({'elements': 'auto', 'lines': 'auto'}) 
            # create a latlong grid using xesmf
            out_grid = xe.util.grid_2d(lat0_b=-22, lat1_b=-14, lon0_b=143, lon1_b=152, d_lat=0.018, d_lon=0.018)
            lon = np.arange(143, 152.018, 0.018)
            lon = xr.DataArray(lon, dims=('lon',), coords={'lon': lon}, attrs={'name': 'Longitude', 'units': 'degree_east'})
            lat = np.arange(-22, -13.982, 0.018)
            lat = xr.DataArray(lat, dims=('lat',), coords={'lat': lat}, attrs={'name': 'Latitude', 'units': 'degree_north'})
            out_grid=xr.Dataset({'lat': lat, 'lon': lon})
            regridder = xe.Regridder(ds_chunked, out_grid, 'bilinear')
            dr = ds_chunked["himawari_8_ahi_channel_13_brightness_temperature"]
            dr_out = regridder(dr)
            # create xr dataset with time coordinates
            dr_out.lon.attrs['units'] = 'degree_east'
            dr_out.lat.attrs['units'] = 'degree_south'
            fn = os.path.basename(file)                                     # extract filepath name
            print(fn)
            date_string = fn[20:30]                                         # extract out datetime info from filename
            date_format = "%Y%j.%H"                                         # give file format
            date_time_obj = datetime.strptime(date_string, date_format)     # convert him8 filename date info to a datetime object
            time = [date_time_obj ]                                         # create array with time values
            time_index = pd.to_datetime(time)
            ds0 = xr.Dataset({'ch13BT':dr_out})
            # add time to dims
            ds_time = ds0.expand_dims(time=[time_index[0]])
            # create xarray dataset
            ds_him8 = xr.Dataset({'ch13BT':ds_time.ch13BT}, 
                            attrs={'note':'JFM ch13BT with smaller domain, natural satellite res (2km) file created with xarray'})
            output.append(ds_him8)
    return output

# %%
# %%time 
# to regrid at natural resolution will take some time ~17min
# regrid_case_1 = diurnal_regrid_av_ch13(case_1) #08,12
# regrid_case_2 = diurnal_regrid_av_ch13(case_2)
regrid_case_study_2021 = diurnal_regrid_av_ch13(case_study_2021[0])
# Out:
# geocatL1.HIMAWARI-8.2021305.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021305.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021306.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021307.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021307.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021307.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021307.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021307.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021307.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021307.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021307.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021307.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021307.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021307.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021307.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021307.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021307.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021307.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021307.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021307.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021308.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021308.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021308.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021308.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021308.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021308.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021308.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021308.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021308.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021308.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021308.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021308.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021308.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021308.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021308.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021308.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021308.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021308.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021308.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021308.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021309.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021310.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021311.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021312.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021313.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021314.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021315.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021316.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021317.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021318.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021319.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021320.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021321.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021322.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021323.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021324.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021325.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021326.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021327.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021328.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021329.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021330.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021331.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021332.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021333.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021334.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021335.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021336.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021337.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021338.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021339.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021340.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021341.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021342.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021343.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021344.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021344.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021344.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021344.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021344.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021344.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021344.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021344.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021344.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021344.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021344.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021344.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021344.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021345.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021346.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021347.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021348.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021348.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021348.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021348.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021348.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021348.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021348.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021348.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021348.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021348.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021348.100000.FLDK.R20.nc
# ...
# geocatL1.HIMAWARI-8.2021351.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021351.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021352.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021353.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021354.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021355.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021356.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021357.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021358.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021359.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021360.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021361.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021362.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021363.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021364.230000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.000000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.010000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.020000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.030000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.040000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.050000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.060000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.070000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.080000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.090000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.100000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.110000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.120000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.130000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.140000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.150000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.160000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.170000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.180000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.190000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.200000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.210000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.220000.FLDK.R20.nc
# geocatL1.HIMAWARI-8.2021365.230000.FLDK.R20.nc
# CPU times: user 3h 57min 4s, sys: 4min 39s, total: 4h 1min 43s
# Wall time: 4h 18min 27s

# %%
# %%time
# now the case studies have been regridded and transformed into an xarray Dataset, they can be analysed far more quickly
regrid_case_study_concat = xr.concat(regrid_case_study_2021,'time')

# saving the files as netcdf # case study 2: 12UTC 25-12-2021 to 12UTC 27-12-2021
regrid_case_study_concat.to_netcdf('case-study_ch13BT_00UTC-01-11-2021_23UTC-31-12-2021.nc', format='NETCDF4', 
             encoding={'ch13BT':{
                       'shuffle':True,         # increases effectiveness of compression when True
                       'chunksizes':[1,446,502], # length of time, lat, lon
                       'zlib':True,            # compression type, required to be True to specify compression levels below
                       'complevel':5           # specifies compression levels, range(0,9) with 0: no compression, 9: fully compressed
            }})
# Out:
# CPU times: user 10min 30s, sys: 2min 34s, total: 13min 4s
# Wall time: 16min 54s

# %% [markdown]
# # Plots

# %% [markdown]
# ### H8

# %%
# open him8 files
case_dec_fp = "/home/563/ac9768/himawari_regridded_files/case-study_ch13BT_12UTC-25-12-2021_12UTC-27-12-2021.nc"
case_jan_fp = "/home/563/ac9768/himawari_regridded_files/case-study_ch13BT_00UTC-22-01-2022_00UTC-24-01-2022.nc"
case_study_nd_fp = "/home/563/ac9768/himawari_regridded_files/case-study_ch13BT_00UTC-01-11-2021_23UTC-31-12-2021.nc"
case_study_jam_fp = "/home/563/ac9768/himawari_regridded_files/case-study_ch13BT_00UTC-01-01-2022_23UTC-31-03-2022.nc"

# %%
case_dec = xr.open_dataset(case_dec_fp,engine="h5netcdf", chunks="auto")
case_jan = xr.open_dataset(case_jan_fp,engine="h5netcdf", chunks="auto")
case_study_nd = xr.open_dataset(case_study_nd_fp,engine="h5netcdf", chunks="auto")
case_study_jam = xr.open_dataset(case_study_jam_fp,engine="h5netcdf", chunks="auto")

# %%
# snapshot plots
# def plot_snapshots():
#     timeslice = case_study_jam.time.sel(time=slice('2022-02-05T10:00:00.000000000','2022-02-15T10:00:00.000000000')).values 
#     for i in timeslice:
fig = plt.figure(figsize=(8,6))
fig.tight_layout()
fig.patch.set_facecolor('white')
sns.set_theme(style="whitegrid")
projPC = ccrs.PlateCarree()
ax = plt.subplot(1, 1, 1, projection=projPC)
snapshot = '2022-02-10T10:00:00' #str(i)
title = snapshot#str(i)#'2022-01-06T06:00:00'
x = case_study_jam.lon.values
y = case_study_jam.lat.values
z = case_study_jam.ch13BT.sel(time=snapshot) 
levels=np.arange(200,330,10)
cf = ax.contourf(x,y,z,levels=levels,cmap="binary")
cb = plt.colorbar(cf,fraction=0.046, pad=0.04) #ax=ax,
x_radar = plotting.longitude.sel(time=time,method="nearest").values
y_radar = plotting.latitude.sel(time=time,method="nearest").values
cf_nan = ax.contourf(x_radar,y_radar,np.isnan(rr_test),levels=1,colors=["white","lightgrey"],alpha=0.8)

# plot gbr locations
ax.scatter(gbr_coordinates[:, 0], gbr_coordinates[:, 1], color='magenta', marker='o',s=0.3)
# ax.set_xlim(143,152)
ax.set_xlim(144.5,147)
# ax.set_ylim(-22,-14)
ax.set_ylim(-18,-15.5)
cb.set_label('Ch.13 BT (K)',fontsize=15)
# xtick = np.arange(143,153,1)
# ax.set_xticks(xtick)
# ytick = np.arange(-22,-13,1)
# ax.set_yticks(ytick)
xtick = np.arange(144.5,147.5,0.5)
ax.set_xticks(xtick)
ytick = np.arange(-18,-15,0.5)
ax.set_yticks(ytick)

ax.coastlines("10m",color="royalblue",linewidth=1.5)
# ax.set_title('Case study 3: 10 UTC 10-01-2022',pad=15)
ax.set_xlabel("Longitude",fontsize=15)
ax.set_ylabel('Latitude',fontsize=15)
# circle_T = mpatches.Circle((146.5509,-19.4198),0.1,fc="orange") # Townsville
circle_C = mpatches.Circle((145.683,-16.817),0.05,fc="orange") # Cairns
# circle_W = mpatches.Circle((149.9646,-16.2874),0.1,fc="orange") # Willis Island
# circle_T_station = mpatches.RegularPolygon((146.77,-19.25), numVertices=3,radius=0.2,alpha=1,fc="red") # Townsville station
circle_C_station = mpatches.RegularPolygon((145.75,-16.87), numVertices=3,radius=0.1,alpha=1,fc="red") 
# ax.add_patch(circle_T_station)
ax.add_patch(circle_C_station)
# ax.add_patch(circle_T)
ax.add_patch(circle_C);
# ax.add_patch(circle_W);
        # plt.savefig("/home/563/ac9768/plots/case_study-jan/" + str(i) + ".png")
        # plt.close()
    # return
# plot_snapshots()

# %%
# convert UTC to LST
import datetime
import pytz
from datetime import datetime, timedelta
# Convert time to pandas datetime objects
time_values = pd.to_datetime(case_study_jam['time'].values,unit='ns')

# Define the longitude of the location (in degrees)
longitude = 145.6 # Cairns

# Convert nanoseconds to datetime objects in UTC
time_objects_utc = pd.to_datetime(time_values, unit='ns')

# Define the time zone for the location
local_timezone = pytz.timezone('Australia/Sydney')

# Convert UTC datetime objects to the local time zone
time_objects_local = time_objects_utc.tz_localize('UTC').tz_convert(local_timezone)

# Calculate the offset from UTC based on the longitude
# 4 minutes per degree of longitude from the prime meridian
longitude_offset = timedelta(minutes=(longitude / 360) * 60)

# Adjust the time to local solar time based on the longitude offset
time_objects_solar = time_objects_local - longitude_offset

# Format datetime objects as strings
time_strings_solar = time_objects_solar.strftime("%Y-%m-%d %H")

# %%
# update time in ds to local solar time
case_study_jam['time'] = time_strings_solar

# %%
# reindex satellite data, adding missing hours
sliced = slice('2022-01-04T23:00:00.000000000','2022-01-07T00:00:00.000000000')
y = case_study_jam.time.sel(time=sliced) 
# Convert time strings to datetime objects
time_objects = [datetime.strptime(time, "%Y-%m-%d %H") for time in y.values]
# Determine the range of hours to fill
min_time = min(time_objects)
max_time = max(time_objects)
# Generate a list of all hours between the min and max times
full_range = [min_time + timedelta(hours=x) for x in range((max_time - min_time).days * 24 + (max_time - min_time).seconds // 3600 + 1)]
# Convert datetime objects back to strings if needed
full_range_strings = [dt.strftime("%Y-%m-%d %H") for dt in full_range]

# %%
case_study_jam_reindexed = case_study_jam.reindex({"time": full_range_strings}, fill_value=np.nan)

# %%
import seaborn as sns
sns.set_theme(style="ticks")

x = case_study_jam_reindexed.isel(time=0).lon.values
# sliced = slice('2022-01-04T23:00:00.000000000','2022-01-07T00:00:00.000000000')
y = case_study_jam_reindexed.time#.sel(time=sliced) #-16.817 #-19.4198
z = case_study_jam_reindexed.ch13BT.sel(lat=-16.817,method="nearest")#.sel(time=sliced) # latitude is for the central Townsville radar site location
levels= np.arange(200,330,10)
cf = plt.contourf(x,y,z,levels=levels,cmap="binary")
cb = plt.colorbar(cf)
cb.set_label('Ch.13 BT (K)',fontsize=15)
site_lon = []
coast = []
lengthoftime = 62
for i in np.arange(0,lengthoftime,1):
    site_lon.append(145.683) #towns:146.5509) 
    coast.append(145.8) # towns: 147.5)
plt.axvline(145.683,linestyle='--',color='darkorange')
plt.axvline(145.8,color='royalblue',linestyle='--')
# plt.title('Case Study 1',pad=15,fontsize=20)
plt.xlabel("Longitude",fontsize=15)
plt.ylabel('Time (LST)',fontsize=15)
yticks = np.arange(0,62,24)
plt.yticks(yticks)
plt.axhline(yticks[1],color="black",linestyle="--",alpha=0.5)
plt.axhline(yticks[2],color="black",linestyle="--",alpha=0.5);

# %% [markdown]
# ### Radar reflectivity

# %%
def path_to_radar_ds(radar_site_no,variable):
    """
    List of yyyymm (year+month) with available radar data.
    For each yyyymm create a list of entire file paths to netCDF4 files.

    Parameters:
    - radar_site_no (str): Radar site number- BoM ID's for radar locations: Townsville=73, Cairns=19, and Willis Island=41 

    Returns:
    - list: list object of netCDF4 files
    """
    # list = ["202201","202202","202203","202204",]
    list = ["202201","202202","202203","202204","202101","202102","202103","202104"]#,"202001","202002","202003","202004","201901","201902","201903","201904",
        #   "201801","201802","201803","201804","201701","201702","201703","201704","201601","201602","201603","201604","201501","201502",
         #  "201503","201504","201401","201402","201403","201404","201301","201302","201303","201304","201201","201202","201203","201204",
          # ] 
    files_list = []
    for i in list:
        fp = "/g/data/rq0/level_2/"+radar_site_no+"/"+variable+"/"
        all_files = [os.path.join(root, f) for root, _, files in os.walk(fp)
            for f in files
            if f.startswith(radar_site_no+'_'+i) and f.endswith('.nc')]
        files_list.extend(all_files)
    files_list.sort()
    return files_list

# towns_radar_files = path_to_radar_ds("73","REFLECTIVITY")
# cairns_radar_files = path_to_radar_ds("19","REFLECTIVITY")
cairns_radar_files = path_to_radar_ds("19","RAINRATE")
# willis_radar_files = path_to_radar_ds("41","REFLECTIVITY")

# %%
# %%time
def open_radar(file_path,threshold): 
    with xr.open_mfdataset(file_path, engine="h5netcdf", chunks="auto") as ds:
        ds_mean = ds.rainrate.mean(dim='time')
        masked_beam_blockage = xr.where((ds_mean < threshold), np.zeros_like(ds_mean),np.ones_like(ds_mean))
        mask_nonvalid_points = ~ds.rainrate.mean(dim='time').isnull()
        mask = masked_beam_blockage.where(mask_nonvalid_points)
        return mask
# reflectivity = open_radar(cairns_radar_files,"reflectivity")
# rr = open_radar(cairns_radar_files,1.2)
rr_test = open_radar(cairns_radar_files,1)
# Out:
# CPU times: user 3min 38s, sys: 37.1 s, total: 4min 15s
# Wall time: 3min 18s

# %%
# %%time
def rr_mean(file_path): 
    with xr.open_mfdataset(file_path, engine="h5netcdf", chunks="auto") as ds:
        ds_mean = ds.rainrate.mean(dim='time')
        # masked = xr.where((ds_mean > threshold), np.zeros_like(ds_mean),np.ones_like(ds_mean))
        # mask = ds_mean.where(masked)
        return ds_mean
rrmean = rr_mean(cairns_radar_files)
# Out:
# CPU times: user 10.8 s, sys: 88 ms, total: 10.9 s
# Wall time: 11.1 s

# %%
rrmean.plot()

# %%
rr_test.plot()

# %%
# %%time 
def open_radar(file_path,threshold): 
    with xr.open_mfdataset(file_path, engine="h5netcdf", chunks="auto") as ds:
        nan_to_zero = ds.rainrate.fillna(0)
        ds_mean = nan_to_zero.mean(dim='time')
        masked_beam_blockage = xr.where((ds_mean < threshold), np.zeros_like(ds_mean),np.ones_like(ds_mean))
        mask = masked_beam_blockage.where(masked_beam_blockage)
        return mask
# reflectivity = open_radar(cairns_radar_files,"reflectivity")
# rr = open_radar(cairns_radar_files,1.2)
rr_test = open_radar(cairns_radar_files,1.2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:10
#
# File <timed exec>:5, in open_radar(file_path, threshold)
#
# File <__array_function__ internals>:180, in ones_like(*args, **kwargs)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/numpy/core/numeric.py:280, in ones_like(a, dtype, order, subok, shape)
#     218 @array_function_dispatch(_ones_like_dispatcher)
#     219 def ones_like(a, dtype=None, order='K', subok=True, shape=None):
#     220     """
#     221     Return an array of ones with the same shape and type as a given array.
#     222
#    (...)
#     278
#     279     """
# --> 280     res = empty_like(a, dtype=dtype, order=order, subok=subok, shape=shape)
#     281     multiarray.copyto(res, 1, casting='unsafe')
#     282     return res
#
# File <__array_function__ internals>:180, in empty_like(*args, **kwargs)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/xarray/core/common.py:165, in AbstractArray.__array__(self, dtype)
#     164 def __array__(self: Any, dtype: DTypeLike | None = None) -> np.ndarray:
# --> 165     return np.asarray(self.values, dtype=dtype)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/xarray/core/dataarray.py:784, in DataArray.values(self)
#     771 @property
#     772 def values(self) -> np.ndarray:
#     773     """
#     774     The array's data converted to numpy.ndarray.
#     775
#    (...)
#     782     to this array may be reflected in the DataArray as well.
#     783     """
# --> 784     return self.variable.values
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/xarray/core/variable.py:525, in Variable.values(self)
#     522 @property
#     523 def values(self):
#     524     """The variable's data as a numpy.ndarray"""
# --> 525     return _as_array_or_item(self._data)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/xarray/core/variable.py:323, in _as_array_or_item(data)
#     309 def _as_array_or_item(data):
#     310     """Return the given values as a numpy array, or as an individual item if
#     311     it's a 0d datetime64 or timedelta64 array.
#     312
#    (...)
#     321     TODO: remove this (replace with np.asarray) once these issues are fixed
#     322     """
# --> 323     data = np.asarray(data)
#     324     if data.ndim == 0:
#     325         if data.dtype.kind == "M":
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/dask/array/core.py:1700, in Array.__array__(self, dtype, **kwargs)
#    1699 def __array__(self, dtype=None, **kwargs):
# -> 1700     x = self.compute()
#    1701     if dtype and x.dtype != dtype:
#    1702         x = x.astype(dtype)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/dask/base.py:375, in DaskMethodsMixin.compute(self, **kwargs)
#     351 def compute(self, **kwargs):
#     352     """Compute this dask collection
#     353
#     354     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     373     dask.compute
#     374     """
# --> 375     (result,) = compute(self, traverse=False, **kwargs)
#     376     return result
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/site-packages/dask/base.py:661, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     658     postcomputes.append(x.__dask_postcompute__())
#     660 with shorten_traceback():
# --> 661     results = schedule(dsk, keys, **kwargs)
#     663 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/queue.py:171, in Queue.get(self, block, timeout)
#     169 elif timeout is None:
#     170     while not self._qsize():
# --> 171         self.not_empty.wait()
#     172 elif timeout < 0:
#     173     raise ValueError("'timeout' must be a non-negative number")
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.01/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
rr_test==False
# Out:
# <xarray.DataArray 'rainrate' (y: 301, x: 301)> Size: 91kB
# dask.array<eq, shape=(301, 301), dtype=bool, chunksize=(301, 301), chunktype=numpy.ndarray>
# Coordinates:
#   * x        (x) int32 1kB -150000 -149000 -148000 ... 148000 149000 150000
#   * y        (y) int32 1kB -150000 -149000 -148000 ... 148000 149000 150000

# %%
rr_test.plot()

# %%
rr.plot()

# %%
# %%time
def mask_rr(file_path,mask): 
    with xr.open_mfdataset(file_path, engine="h5netcdf", chunks="auto").sel(time=slice('2022-01-05T10:00:00.000000000','2022-01-11T10:00:00.000000000')) as ds:
        masked_ds = ds.rainrate.where(mask)
        return masked_ds
masked_ds = mask_rr(cairns_radar_files,rr_test)
# Out:
# CPU times: user 10.4 s, sys: 97.8 ms, total: 10.5 s
# Wall time: 10.7 s

# %%
# %%time
def ds_not_masked(file_path): 
    with xr.open_mfdataset(file_path, engine="h5netcdf", chunks="auto").sel(time=slice('2022-02-05T10:00:00.000000000','2022-02-11T10:00:00.000000000')) as ds:
        return ds
plotting = ds_not_masked(cairns_radar_files)
# Out:
# CPU times: user 9.94 s, sys: 75.3 ms, total: 10 s
# Wall time: 10.2 s

# %%
# %%time
fig = plt.figure(figsize=(8,6))
fig.tight_layout()
fig.patch.set_facecolor('white')
sns.set_theme(style="whitegrid")
projPC = ccrs.PlateCarree()
ax = plt.subplot(1, 1, 1, projection=projPC)
time= "2022-02-10T10:00:00.000000000"
x = plotting.longitude.sel(time=time,method="nearest").values
y = plotting.latitude.sel(time=time,method="nearest").values
z = masked_ds.sel(time=time,method="nearest")
levels = [0,0.5,1,2,4,456]
cf_bb = ax.contourf(x,y,rr_test==False,levels=1,colors=["white","lightgrey"],alpha=0.5)
cf_nan = ax.contourf(x,y,np.isnan(rr_test),levels=1,colors=["white","lightgrey"],hatches=['/'],alpha=0.5)

colors = ['#084594', '#4292c6', 'seagreen','#addd8e', '#f7fcb9','pink','red']
cf = ax.contourf(x,y,z,levels=levels,colors=colors)
cb = plt.colorbar(cf,ax=ax)
cb.set_label("mm/h",fontsize=15)
xtick = np.arange(144.5,147.5,0.5)
ax.set_xticks(xtick)
ytick = np.arange(-18,-15,0.5)
ax.set_yticks(ytick)
ax.coastlines("10m",color="royalblue",linewidth=1.5)
ax.grid(None)
# ax.set_title(time[0:19])
ax.set_ylabel("Latitude",fontsize=15)
ax.set_xlabel("Longitude",fontsize=15)
# Out:
# CPU times: user 4min 56s, sys: 49.4 s, total: 5min 46s
# Wall time: 3min 53s
# Text(0.5, 0, 'Longitude')
