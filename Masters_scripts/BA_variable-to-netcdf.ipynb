# %% [markdown]
# # This notebook contains:
# * Functions to create an xarray dataset and netcdf file for a particular BARRA2 variable over JFMA

# %%
# import libraries
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import warnings
import sys
import metpy
import matplotlib
import matplotlib.gridspec as gridspec
import matplotlib.colors as mcolors
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import metpy.calc as mpcalc
import pandas as pd
from netCDF4 import Dataset
import os
import glob
from datetime import datetime
import seaborn as sns
import netCDF4
from netCDF4 import Dataset
from metpy.units import units
import dask
import xarray as xr
from shapely import Polygon
import regionmask
import geopandas as gpd
import dask
from scipy.stats import circmean

# %%
# near surface:
def file_paths(variable):
    list = ["202201-202201","202202-202202","202101-202101","202102-202102","202103-202103","202104-202104","202001-202001","202002-202002",
           "202003-202003","202004-202004","201901-201901","201902-201902","201903-201903","201904-201904","201801-201801","201802-201802",
           "201803-201803","201804-201804","201701-201701","201702-201702","201703-201703","201704-201704","201601-201601","201602-201602",
           "201603-201603","201604-201604","201501-201501","201502-201502","201503-201503","201504-201504","201401-201401","201402-201402",
           "201403-201403","201404-201404","201301-201301","201302-201302","201303-201303","201304-201304","201201-201201","201202-201202",
           "201203-201203","201204-201204"]
    list.sort()
    file_paths = []
    for i in list:
        fp = "/g/data/ob53/BARRA2/output/reanalysis/AUS-11/BOM/ERA5/historical/hres/BARRA-R2/v1/1hr/"+variable+"/v20231001/"
        all_files = [fp+variable+"_AUS-11_ERA5_historical_hres_BOM_BARRA-R2_v1_1hr_"+i+".nc"]
        file_paths.extend(all_files)
    file_paths.sort()
    return file_paths  
u_surface = file_paths("uas") # in m/s
v_surface = file_paths("vasmean") # in m/s
# u100m = file_paths("ua100m") # in m/s # v100m = file_paths("va100m") # in m/s # wind_speed = file_paths("sfcWind") # in m/s # sfc_temp = file_paths("tas") # in K # u850 = file_paths("ua850") # in m/s
# v850 = file_paths("va850") #  in m/s # u500 = file_paths("ua500") #  in m/s # v500 = file_paths("va500") #  in m/s
sfc_dw_LW = file_paths("rlds")
# sfc_dw_clr_LW = file_paths("rldscs") # sfc_uw_LW = file_paths("rlus") # sfc_uw_clr_LW = file_paths("rluscs") # sfc_dw_SW = file_paths("rsds") # sfc_dw_clr_SW = file_paths("rsdscs")
# sfc_uw_SW = file_paths("rsus") # sfc_uw_clr_SW = file_paths("rsuscs") # sfc_direct_dw_SW = file_paths("rsdsdir") # sfc_up_sensible = file_paths("hfss") # sfc_up_latent = file_paths("hfls")

# %%
# %%time
def open_and_select_lat(file_path,variable):
    with xr.open_mfdataset(file_path, engine="h5netcdf", chunks="auto") as ds: # for station 
        towns = ds[variable].sel(lat=-19.4198,method="nearest").sel(lon=slice(143,152))  #lat=-19.4198,lon=146.5509,method="nearest")#(
        cairns = ds[variable].sel(lat=-16.8736,method="nearest").sel(lon=slice(143,152))  #(lat=-16.8736,lon=145.7458,method="nearest")                    
        willis = ds[variable].sel(lat=-16.2874,method="nearest").sel(lon=slice(143,152))  #(lat=-16.2874,lon=149.9646,method="nearest")
        return (towns*units("m/s")).compute(),(cairns*units("m/s")).compute(),(willis*units("m/s")).compute()
# u100T,u100C,u100W = open_and_select_lat(u100m,"ua100m")
# v100T,v100C,v100W = open_and_select_lat(v100m,"va100m")
uuT,uuC,uuW = open_and_select_lat(u_surface,"uas")
# vvT,vvC,vvW = open_and_select_lat(v_surface,"vasmean")
# tas_meanT,tas_meanC,tas_meanW = open_and_select_lat(sfc_temp,"tas")

# sfc_dw_LWt,sfc_dw_LWc,sfc_dw_LWw = open_and_select_lat(sfc_dw_LW,"rlds")
# sfc_dw_clr_LWt,sfc_dw_clr_LWc,sfc_dw_clr_LWw = open_and_select_lat(sfc_dw_clr_LW,"rldscs")
# sfc_uw_LWt,sfc_uw_LWc,sfc_uw_LWw = open_and_select_lat(sfc_uw_LW,"rlus")
# sfc_uw_clr_LWt,sfc_uw_clr_LWc,sfc_uw_clr_LWw = open_and_select_lat(sfc_uw_clr_LW,"rluscs")
# sfc_dw_SWt,sfc_dw_SWc,sfc_dw_SWw = open_and_select_lat(sfc_dw_SW,"rsds")
# sfc_dw_clr_SWt,sfc_dw_clr_SWc,sfc_dw_clr_SWw = open_and_select_lat(sfc_dw_clr_SW,"rsdscs")
# sfc_uw_SWt,sfc_uw_SWc,sfc_uw_SWw = open_and_select_lat(sfc_uw_SW,"rsus")
# sfc_uw_clr_SWt,sfc_uw_clr_SWc,sfc_uw_clr_SWw = open_and_select_lat(sfc_uw_clr_SW,"rsuscs")
# sfc_direct_dw_SWt,sfc_direct_dw_SWc,sfc_direct_dw_SWw = open_and_select_lat(sfc_direct_dw_SW,"rsdsdir")
# sfc_up_sensiblet,sfc_up_sensiblec,sfc_up_sensiblew = open_and_select_lat(sfc_up_sensible,"hfss")
# sfc_up_latentt,sfc_up_latentc,sfc_up_latentw = open_and_select_lat(sfc_up_latent,"hfls")
# Out:
# CPU times: user 1min 9s, sys: 3.46 s, total: 1min 13s
# Wall time: 2min 2s

# %%
uuT
# Out:
# <xarray.DataArray 'uas' (time: 30288, lon: 82)> Size: 20MB
# <Quantity([[-2.28125 -2.25    -2.71875 ... -6.5625  -6.625   -6.78125]
#  [-0.8125  -0.8125  -1.28125 ... -6.625   -6.78125 -6.78125]
#  [-0.90625 -1.21875 -1.1875  ... -6.5625  -6.59375 -6.59375]
#  ...
#  [-0.375   -0.625   -0.59375 ...  2.5625   2.6875   2.8125 ]
#  [ 0.125    0.125    0.28125 ...  2.78125  2.78125  2.8125 ]
#  [ 1.3125   1.34375  1.5     ...  3.15625  3.21875  3.25   ]], 'meter / second')>
# Coordinates:
#   * time     (time) datetime64[ns] 242kB 2012-01-01 ... 2022-02-28T23:00:00
#     height   float64 8B 10.0
#   * lon      (lon) float64 656B 143.0 143.1 143.3 143.4 ... 151.7 151.8 151.9
#     lat      float64 8B -19.47

# %%
# combine xarrays into xarray dataset
towns_wind = xr.Dataset({'u':uuT},
            attrs={'note':'JFMA surface u winds for townsville latitude slice (longitude 143-152deg) created with xarray'})
cairns_wind = xr.Dataset({'u':uuC},
            attrs={'note':'JFMA surface u winds for cairns latitude slice (longitude 143-152deg) created with xarray'})
willis_wind = xr.Dataset({'u':uuW},
            attrs={'note':'JFMA surface u winds for willis island latitude slice (longitude 143-152deg) created with xarray'})

# %%
# %%time
# function for calculating mean 850hPa wind regimes over the radar domains
def open_and_calc_mean(file_path,variable):
    with xr.open_mfdataset(file_path, engine="h5netcdf", chunks="auto") as ds:
        towns = ds[variable].sel(lat=slice(-20.768799,-18.0708),lon=slice(145.12054,147.9812)).mean(dim=["lat","lon"])
        cairns = ds[variable].sel(lat=slice(-18.165955,-15.468018),lon=slice(144.27374,147.09222)).mean(dim=["lat","lon"])                  
        willis = ds[variable].sel(lat=slice(-17.636353,-14.938416),lon=slice(148.55927,151.36993)).mean(dim=["lat","lon"])
        return (towns*units("m/s")).compute(),(cairns*units("m/s")).compute(),(willis*units("m/s")).compute()
uuT,uuC,uuW = open_and_calc_mean(u_surface,"uas")
vvT,vvC,vvW = open_and_calc_mean(v_surface,"vasmean")
# Out:
# CPU times: user 7min 2s, sys: 2min 11s, total: 9min 14s
# Wall time: 14min 19s

# %%
# %%time
# wind speeds and calculations
towns_wind_dir = metpy.calc.wind_direction(uuT,vvT,convention='from')
towns_wind_speed = metpy.calc.wind_speed(uuT,vvT)
cairns_wind_dir = metpy.calc.wind_direction(uuC,vvC,convention='from')
cairns_wind_speed = metpy.calc.wind_speed(uuC,vvC)
willis_wind_dir = metpy.calc.wind_direction(uuW,vvW,convention='from')
willis_wind_speed = metpy.calc.wind_speed(uuW,vvW)
# Out:
# CPU times: user 29.2 ms, sys: 3.15 ms, total: 32.3 ms
# Wall time: 43.6 ms

# %%
# change from pint quantity to array for open_and_calc_mean arrays
time_values = towns_wind_dir.time.values
towns_wind_speed_array = xr.DataArray(towns_wind_speed.values,dims=('time'), coords={'time': time_values})
towns_wind_dir_array = xr.DataArray(towns_wind_dir.values,dims=('time'), coords={'time': time_values})
cairns_wind_speed_array = xr.DataArray(cairns_wind_speed.values,dims=('time'), coords={'time': time_values})
cairns_wind_dir_array = xr.DataArray(cairns_wind_dir.values,dims=('time'), coords={'time': time_values})
willis_wind_speed_array = xr.DataArray(willis_wind_speed.values,dims=('time'), coords={'time': time_values})
willis_wind_dir_array = xr.DataArray(willis_wind_dir.values,dims=('time'), coords={'time': time_values})

# %%
# combine xarrays into xarray dataset
towns_wind = xr.Dataset({'wind_dir':towns_wind_dir_array,
                         'wind_speed':towns_wind_speed_array}, 
            attrs={'note':'JFMA surface winds for townsville latitude slice (longitude 143-152deg) created with xarray'}) #JFMA mean 500hPa winds for townsville radar domain created with xarray
cairns_wind = xr.Dataset({'wind_dir':cairns_wind_dir_array,
                         'wind_speed':cairns_wind_speed_array}, 
            attrs={'note':'JFMA surface winds for cairns latitude slice (longitude 143-152deg) created with xarray'})
willis_wind = xr.Dataset({'wind_dir':willis_wind_dir_array,
                         'wind_speed':willis_wind_speed_array}, 
            attrs={'note':'JFMA surface winds for willis island latitude slice (longitude 143-152deg) created with xarray'})

# surface energy budget
# combine xarrays into xarray dataset
towns_radiation = xr.Dataset({'sfc_dw_LW':sfc_dw_LWt,
                             'sfc_dw_clr_LW':sfc_dw_clr_LWt,
                             'sfc_uw_LW':sfc_uw_LWt,
                             'sfc_uw_clr_LW':sfc_uw_clr_LWt,
                             'sfc_dw_SW':sfc_dw_SWt,
                             'sfc_dw_clr_SW':sfc_dw_clr_SWt,
                             'sfc_uw_SW':sfc_uw_SWt,
                             'sfc_uw_clr_SW':sfc_uw_clr_SWt,
                             'sfc_direct_dw_SW':sfc_direct_dw_SWt,
                             'sfc_up_sensible':sfc_up_sensiblet,
                             'sfc_up_latent':sfc_up_latentt}, 
            attrs={'note':'JFMA mean surface energy budget variables for townsville longitude (between 143 and 152deg) created with xarray'})

# %%
# save surface wind speed and wind direction
willis_wind.to_netcdf('barra-2_sfc-u-winds_willis.nc', format='NETCDF4', 
             encoding={'u':{
                       'shuffle':True,         # increases effectiveness of compression when True
                       'chunksizes':[1,82], # length of time, lat, lon
                       'zlib':True,            # compression type, required to be True to specify compression levels below
                       'complevel':5           # specifies compression levels, range(0,9) with 0: no compression, 9: fully compressed
            },
                      # 'wind_speed':{
                      # 'shuffle':True,         # increases effectiveness of compression when True
                      #  'chunksizes':[1], # length of time, lat, lon (82)
                      #  'zlib':True,            # compression type, required to be True to specify compression levels below
                      #  'complevel':5  
                      })
